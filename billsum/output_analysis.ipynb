# %%
import json

input_file = "experiments/gemma_1b_sft/v3/us_test_w_metrics.jsonl"

idx = 0
for line in open(input_file):
    instance = json.loads(line.strip())
    if idx == 1:
        print(instance["text"])
        print(instance["predictions"])
        print(instance["summary"])
        break
    idx += 1

# %%
import json

input_file = "dataset/org/us_train_data_final_OFFICIAL.jsonl"

idx = 0
for line in open(input_file):
    instance = json.loads(line.strip())
    if idx >= 0:
        if instance["summary"].strip().startswith("Amends"):
            print(instance["summary"])
            break
        
    idx += 1
